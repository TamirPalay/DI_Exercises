# %% [markdown]
# <a href="https://colab.research.google.com/github/TamirPalay/DI_Exercises/blob/main/week12/day1-2/GenAI_197_W12D1_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GenAI_197 - W12D1 - Tutorial

# %% [markdown]
# ## 1. Choosing our Model & Dataset

# %%
MY_MODEL="openai-community/gpt2"
MY_DATASET="mteb/tweet_sentiment_extraction"

# %% [markdown]
# ## 2. Data Loading and Exploration

# %%
from datasets import load_dataset
import pandas as pd
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer
import evaluate
import numpy as np

dataset = load_dataset(MY_DATASET)

# Load only a subset of the dataset (so the training phase doesnt take too long)
train_data = dataset["train"].shuffle(seed=42).select(range(500))
test_data = dataset["test"].shuffle(seed=42).select(range(200))
