# %%
# !unzip Data Science Job Salary dataset.zip
# Out:
# 'unzip' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# # Normalise salary column

# %%
from sklearn.preprocessing import  MinMaxScaler
from sklearn.decomposition import PCA
import pandas as pd
df = pd.read_csv('datascience_salaries.csv')
# experience_levels=df['experience_level'].unique()
# print(experience_levels)
# Group by experience_level and calculate average and median salary
grouped = df.groupby('experience_level')['salary'].agg(['mean', 'median'])
print(grouped)

#df.head()
scaler=MinMaxScaler()
df['salary']=scaler.fit_transform(df['salary'].values.reshape(-1,1))
print(df['salary'].min())
print(df['salary'].max())
print(df['salary'].mean())



print("number of columns: ", len(df.columns))
numeric_df = df.select_dtypes(include=[np.number])
pca = PCA(n_components=2)
reduced_data = pca.fit_transform(numeric_df)
print("number of columns after PCA: ", reduced_data.shape[1])
print("new dataframe after PCA: ", reduced_data)
# Out:
#                           mean   median
# experience_level
# Entry             36111.111111  30000.0
# Executive         76076.923077  46000.0
# Mid               51786.885246  51000.0
# Senior            75088.033012  68000.0
# 0.0
# 1.0
# 0.1759395837107195
